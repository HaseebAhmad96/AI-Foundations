# %%
# !pip install groq
# Out:
# Collecting groq
#   Downloading groq-1.1.1-py3-none-any.whl (139 kB)
#      -------------------------------------- 139.7/139.7 kB 1.4 MB/s eta 0:00:00
# Collecting anyio<5,>=3.5.0
#   Downloading anyio-4.12.1-py3-none-any.whl (113 kB)
#      -------------------------------------- 113.6/113.6 kB 6.5 MB/s eta 0:00:00
# Collecting pydantic<3,>=1.9.0
#   Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
#      -------------------------------------- 463.6/463.6 kB 4.8 MB/s eta 0:00:00
# Collecting sniffio
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\thinkpad\appdata\roaming\python\python310\site-packages (from groq) (4.15.0)
# Collecting distro<2,>=1.7.0
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting httpx<1,>=0.23.0
#   Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#      ---------------------------------------- 73.5/73.5 kB 2.0 MB/s eta 0:00:00
# Collecting idna>=2.8
#   Downloading idna-3.11-py3-none-any.whl (71 kB)
#      ---------------------------------------- 71.0/71.0 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\thinkpad\appdata\roaming\python\python310\site-packages (from anyio<5,>=3.5.0->groq) (1.3.1)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.8/78.8 kB 4.3 MB/s eta 0:00:00
# Collecting certifi
#   Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
#      -------------------------------------- 153.7/153.7 kB 4.6 MB/s eta 0:00:00
# Collecting h11>=0.16
#   Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Collecting typing-inspection>=0.4.2
#   Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.41.5
#   Downloading pydantic_core-2.41.5-cp310-cp310-win_amd64.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 1.4 MB/s eta 0:00:00
# Installing collected packages: typing-inspection, sniffio, pydantic-core, idna, h11, distro, certifi, annotated-types, pydantic, httpcore, anyio, httpx, groq
# Successfully installed annotated-types-0.7.0 anyio-4.12.1 certifi-2026.2.25 distro-1.9.0 groq-1.1.1 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.11 pydantic-2.12.5 pydantic-core-2.41.5 sniffio-1.3.1 typing-inspection-0.4.2
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install dotenv
# Out:
# Collecting dotenv
#   Downloading dotenv-0.9.9-py2.py3-none-any.whl (1.9 kB)
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: python-dotenv, dotenv
# Successfully installed dotenv-0.9.9 python-dotenv-1.2.2
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import time
from groq import Groq
from dotenv import load_dotenv

# %%
load_dotenv()
client = Groq(api_key=os.getenv("Groq_API"))

# %%
user_prompt = input("Enter concise prompt for AI response")

# %%
start = time.time()

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages = [{"role": "user", "content": user_prompt}],
    max_tokens = 250,
    temperature = 0.6,
)

end = time.time()

# %%
usage = response.usage
prompt_tokens = usage.prompt_tokens
completion_tokens = usage.completion_tokens
total_tokens = usage.total_tokens

cost_per_token = 0.002
total_estimated_cost = total_tokens * cost_per_token

# %%
print("Provider:", "Groq")
print("Response:", response.choices[0].message.content)
print("Response Time:", (end - start), "seconds")
print("Prompt Tokens:", prompt_tokens)
print("Completion Tokens:", completion_tokens)
print("Total Tokens:", total_tokens)
print("Estimated Cost:", total_estimated_cost,"$")
# Out:
# Provider: Groq
# Response: **Convolutional Neural Networks (CNNs)**
#
# Convolutional Neural Networks (CNNs) are a type of deep learning model that are commonly used for image and video processing tasks. They are designed to take advantage of the spatial structure of data, such as images, and are particularly useful for tasks like:
#
# * Image classification
# * Object detection
# * Image segmentation
# * Image generation
#
# ### Key Components of CNNs
#
# 1. **Convolutional Layers**: These layers apply filters to the input data, scanning the data in a sliding window fashion to extract features.
# 2. **Activation Functions**: These introduce non-linearity into the model, allowing it to learn complex relationships between the input data.
# 3. **Pooling Layers**: These layers reduce the spatial dimensions of the data, helping to downsample the data and reduce the number of parameters.
# 4. **Fully Connected Layers**: These layers are used to make predictions based on the features extracted by the convolutional and pooling layers.
#
# ### How CNNs Work
#
# 1. **Convolution**: The input data is convolved with a set of filters, producing feature maps that represent the presence of certain features in the data.
# 2. **Activation**: The feature maps are passed through an activation function,
# Response Time: 1.2045564651489258 seconds
# Prompt Tokens: 39
# Completion Tokens: 250
# Total Tokens: 289
# Estimated Cost: 0.578 $
